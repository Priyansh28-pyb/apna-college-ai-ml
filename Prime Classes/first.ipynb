# %%
print("Hello World")
# Out:
# Hello World

# %%
a= 5
b = 6
print(a+b)
# Out:
# 11

# %%
print("Using cntrl + enter") #for running single selected cell
# Out:
# Using cntrl + enter

# %%
print("Using shift + enter") #for runing current cell and move to next one
# Out:
# Using shift + enter
